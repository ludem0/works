# %% [markdown]
# **Оглавление:**
# 1. [Описание проекта](#описание)
# 2. [Загрузка данных](#загрузка)
# 3. [Предобработка данных](#предобработка)
# 4. [Исследовательский анализ данных](#исследовательский)
# 5. [Объединение таблиц](#объединение)
# 6. [Корреляционный анализ признаков](#корреляция)
# 7. [Использование пайплайнов](#пайплайн)
# 8. [Анализ важности признаков](#важность)
# 9. [Сегментация покупателей](#сегментация)
# 10. [Итоговые выводы](#выводы)

# %% [markdown]
# # Описание проекта
# <a id="описание"></a>

# %% [markdown]
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.
# «В один клик» — современная компания, поэтому её руководство не хочет принимать решения просто так — только на основе анализа данных и бизнес-моделирования. У компании есть небольшой отдел цифровых технологий, и вам предстоит побыть в роли стажёра в этом отделе.
# Итак, вашему отделу поручили разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.

# %% [markdown]
# 1. Нужно промаркировать уровень финансовой активности постоянных покупателей. В компании принято выделять два уровня активности: «снизилась», если клиент стал покупать меньше товаров, и «прежний уровень».
# 2. Нужно собрать данные по клиентам по следующим группам:
# * Признаки, которые описывают коммуникацию сотрудников компании с клиентом.
# * Признаки, которые описывают продуктовое поведение покупателя. Например, какие товары покупает и как часто.
# * Признаки, которые описывают покупательское поведение клиента. Например, сколько тратил в магазине.
# * Признаки, которые описывают поведение покупателя на сайте. Например, как много страниц просматривает и сколько времени проводит на сайте.

# %% [markdown]
# Представим группы признаков (вместе с целевым) в виде диаграммы — такую визуализацию ещё называют диаграммой Исикавы.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Нужно построить модель, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца.
# 2. В исследование нужно включить дополнительные данные финансового департамента о прибыльности клиента: какой доход каждый покупатель приносил компании за последние три месяца.
# 3. Используя данные модели и данные о прибыльности клиентов, нужно выделить сегменты покупателей и разработать для них персонализированные предложения.

# %% [markdown]
# **Цели работы:**
# - Проанализировать данные: выявить ключевые признаки, которые влияют на снижение покупательской активности клиентов
# - Подготовить данные: обработать пропуски, закодировать категориальные признаки, устранить мультиколлинеарность и другие аномалии
# - Провести исследовательский анализ данных: изучить корреляции между признаками и целевой переменной, выделить наиболее важные факторы
# - Построить модель машинного обучения для предсказания вероятности снижения покупательской активности клиентов
# - Оценить качество модели с использованием соответствующих метрик
# - Сегментировать клиентов
# - Подготовить рекомендации для отдела маркетинга по улучшению клиентской активности

# %% [markdown]
# **План работы:**
# * Изучить общую информацию о данных
# * Провести предобработку данных
# * Провести исследовательский анализ данных
# * Провести корреляционный анализ данных
# * Построить модели машинного обучения
# * Оценить качество моделей с использованием метрик
# * Сегментировать клиентов
# * Подготовить рекомендации

# %% [markdown]
# **Описание данных:**
#
# market_file.csv:
#
# * id — номер покупателя в корпоративной базе данных.
# * Покупательская активность — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
# * Тип сервиса — уровень сервиса, например «премиум» и «стандарт».
# * Разрешить сообщать — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
# * Маркет_актив_6_мес — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
# * Маркет_актив_тек_мес — количество маркетинговых коммуникаций в текущем месяце.
# * Длительность — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
# * Акционные_покупки — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
# * Популярная_категория — самая популярная категория товаров у покупателя за последние 6 месяцев.
# * Средний_просмотр_категорий_за_визит — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
# * Неоплаченные_продукты_штук_квартал — общее число неоплаченных товаров в корзине за последние 3 месяца.
# * Ошибка_сервиса — число сбоев, которые коснулись покупателя во время посещения сайта.
# * Страниц_за_визит — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.

# %% [markdown]
# market_money.csv:
# * id — номер покупателя в корпоративной базе данных.
# * Период — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц'.
# * Выручка — сумма выручки за период.

# %% [markdown]
# market_time.csv:
# * id — номер покупателя в корпоративной базе данных.
# * Период — название периода, во время которого зафиксировано общее время.
# * минут — значение времени, проведённого на сайте, в минутах.

# %% [markdown]
# money.csv:
# * id — номер покупателя в корпоративной базе данных.
# * Прибыль — значение прибыли.

# %%
# Код ревьюера


 
# !pip install -U scikit-learn

# %% [markdown]
# ## Загрузка данных
# <a id="загрузка"></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from scipy import stats as st
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
# !pip install -q phik
from phik.report import plot_correlation_matrix
from phik import phik_matrix
from sklearn.preprocessing import (
    OneHotEncoder, StandardScaler, OrdinalEncoder,
    MinMaxScaler, LabelEncoder
)
from sklearn.metrics import (
    r2_score, mean_absolute_error, mean_squared_error,
    accuracy_score, precision_score, recall_score,
    confusion_matrix, f1_score, roc_auc_score, roc_curve,
    RocCurveDisplay, RocCurveDisplay
)
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
# !pip install -q shap 
import shap
from sklearn.metrics import f1_score

# %%
RANDOM_STATE = 42

# %%
data_market_file = pd.read_csv("/datasets/market_file.csv", sep = ",")
data_market_money = pd.read_csv("/datasets/market_money.csv", sep = ",")
data_market_time = pd.read_csv("/datasets/market_time.csv", sep = ",")
data_money = pd.read_csv("/datasets/money.csv", sep = ";", decimal = ",")

# %%
display(data_market_file.head())
# Out:
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   Популярная_категория  Средний_просмотр_категорий_за_визит  \
# ...

# %%
data_market_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %%
display(data_market_money.head())
# Out:
#        id               Период  Выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# 2  215348     предыдущий_месяц      0.0
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6

# %%
data_market_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# Выручка имеет неправильный тип данных

# %%
display(data_market_time.head())
# Out:
#        id            Период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13

# %%
data_market_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %%
display(data_money.head())
# Out:
#        id  Прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21

# %%
data_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %% [markdown]
# **Итоги по обзору данных:**
# * Пропуски отсутствуют
# * Есть проблемы с названиями столбцов, нужно привести в змеиный регистр
# * Данные в столбце market_time (период) содержат опечатку.

# %% [markdown]
# ## Предобработка данных
# <a id="предобработка"></a>

# %%
data_market_file.columns = data_market_file.columns.str.lower()
data_market_money.columns = data_market_money.columns.str.lower()
data_market_time.columns = data_market_time.columns.str.lower()
data_money.columns = data_money.columns.str.lower()

# %%
def lower(data):
    return data.columns.str.lower()

# %%
def add_underscore(data):
    data.columns = [name.replace(" ", "_") for name in data.columns]

# %%
add_underscore(data_market_file)
add_underscore(data_market_money)
add_underscore(data_market_time)
add_underscore(data_money)

# %%
display(data_market_file)
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0     215348                 Снизилась     премиум                 да
# 1     215349                 Снизилась     премиум                 да
# 2     215350                 Снизилась   стандартт                нет
# 3     215351                 Снизилась   стандартт                 да
# 4     215352                 Снизилась   стандартт                нет
# ...      ...                       ...         ...                ...
# 1295  216643           Прежний уровень    стандарт                 да
# 1296  216644           Прежний уровень    стандарт                нет
# 1297  216645           Прежний уровень    стандарт                 да
# 1298  216646           Прежний уровень    стандарт                 да
# 1299  216647           Прежний уровень     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 0                    3.4                     5           121
# ...

# %%
display(data_market_money)
# Out:
#           id               период  выручка
# 0     215348  препредыдущий_месяц      0.0
# 1     215348        текущий_месяц   3293.1
# 2     215348     предыдущий_месяц      0.0
# 3     215349  препредыдущий_месяц   4472.0
# 4     215349        текущий_месяц   4971.6
# ...      ...                  ...      ...
# 3895  216646  препредыдущий_месяц   4725.0
# 3896  216646     предыдущий_месяц   4923.0
# 3897  216647     предыдущий_месяц   4720.0
# 3898  216647  препредыдущий_месяц   5183.0
# 3899  216647        текущий_месяц   4448.3
#
# [3900 rows x 3 columns]

# %%
display(data_market_time)
# Out:
#           id            период  минут
# 0     215348     текущий_месяц     14
# 1     215348  предыдцщий_месяц     13
# 2     215349     текущий_месяц     10
# 3     215349  предыдцщий_месяц     12
# 4     215350     текущий_месяц     13
# ...      ...               ...    ...
# 2595  216645     текущий_месяц     18
# 2596  216646  предыдцщий_месяц     18
# 2597  216646     текущий_месяц      7
# 2598  216647     текущий_месяц     10
# 2599  216647  предыдцщий_месяц     15
#
# [2600 rows x 3 columns]

# %%
display(data_money)
# Out:
#           id  прибыль
# 0     215348     0.98
# 1     215349     4.16
# 2     215350     3.13
# 3     215351     4.87
# 4     215352     4.21
# ...      ...      ...
# 1295  216643     4.44
# 1296  216644     6.11
# 1297  216645     3.29
# 1298  216646     4.03
# 1299  216647     3.28
#
# [1300 rows x 2 columns]

# %% [markdown]
# **Все названия столбцов были приведены в корректный формат(змеиный регистр)**

# %%
data_market_file.isna().sum()
# Out:
# id                                     0
# покупательская_активность              0
# тип_сервиса                            0
# разрешить_сообщать                     0
# маркет_актив_6_мес                     0
# маркет_актив_тек_мес                   0
# длительность                           0
# акционные_покупки                      0
# популярная_категория                   0
# средний_просмотр_категорий_за_визит    0
# неоплаченные_продукты_штук_квартал     0
# ошибка_сервиса                         0
# страниц_за_визит                       0
# dtype: int64

# %%
data_market_money.isna().sum()
# Out:
# id         0
# период     0
# выручка    0
# dtype: int64

# %%
data_market_time.isna().sum()
# Out:
# id        0
# период    0
# минут     0
# dtype: int64

# %%
data_money.isna().sum()
# Out:
# id         0
# прибыль    0
# dtype: int64

# %% [markdown]
# **Пропусков нет**

# %%
data_market_file["популярная_категория"].unique()
# Out:
# array(['Товары для детей', 'Домашний текстиль', 'Косметика и аксесуары',
#        'Техника для красоты и здоровья', 'Кухонная посуда',
#        'Мелкая бытовая техника и электроника'], dtype=object)

# %%
data_market_file["тип_сервиса"].unique()
# Out:
# array(['премиум', 'стандартт', 'стандарт'], dtype=object)

# %%
data_market_time["период"].unique()
# Out:
# array(['текущий_месяц', 'предыдцщий_месяц'], dtype=object)

# %%
data_market_money["период"].unique()
# Out:
# array(['препредыдущий_месяц', 'текущий_месяц', 'предыдущий_месяц'],
#       dtype=object)

# %%
data_market_file["тип_сервиса"] = data_market_file["тип_сервиса"].replace("стандартт", "стандарт")

# %%
data_market_time["период"] = data_market_time["период"].replace("предыдцщий_месяц", "предыдущий_месяц")

# %%
data_market_money["период"].unique()
# Out:
# array(['препредыдущий_месяц', 'текущий_месяц', 'предыдущий_месяц'],
#       dtype=object)

# %%
data_market_time["период"].unique()
# Out:
# array(['текущий_месяц', 'предыдущий_месяц'], dtype=object)

# %%
data_market_file["тип_сервиса"].unique()
# Out:
# array(['премиум', 'стандарт'], dtype=object)

# %% [markdown]
# **Неявные дубликаты и опечатки в данных были устранены**

# %%
data_market_file.duplicated().sum()
# Out:
# 0

# %%
data_market_money.duplicated().sum()
# Out:
# 0

# %%
data_market_time.duplicated().sum()
# Out:
# 0

# %%
data_money.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Явных дубликатов нет**

# %% [markdown]
# **Итоги предобработки данных:**
#
# * Названия столбцов приведены к корректному формату (змеиный регистр).
# * Пропусков в данных нет
# * Явных дубликатов в данных нет
# * Неявные дубликаты и опечатки в данных были устранены

# %% [markdown]
# ## Исследовательский анализ данных
# <a id="исследовательский"></a>

# %%
def plot_hist(data, name, number, x_beg = None, x_end = None):
    data[name].plot(kind="hist", bins = number, figsize=(10,5), title=f"Гистограмма для '{name}'", grid = True, edgecolor = "black")
    plt.xlabel(f"{name}")
    plt.ylabel("Частота")
    if x_beg is not None and x_end is not None:
        plt.xlim(x_beg, x_end)
    plt.show()

# %%
def plot_bar(data, name, x_beg = None, x_end = None):
    data[name].plot(kind="bar", figsize=(10,5), title=f"Гистограмма для '{name}'", grid = True, edgecolor = "black")
    plt.xlabel(f"{name}")
    plt.ylabel("Частота")
    if x_beg is not None and x_end is not None:
        plt.xlim(x_beg, x_end)
    plt.show()

# %%
def plot_box(data, name, lower, upper):
    plt.ylim(lower, upper)
    data.boxplot(name)

# %%
def plot_pie(data, name):
    count = data[name].value_counts()
    plt.figure(figsize=(10, 5))
    count.plot(kind="pie", autopct="%1.1f%%", startangle=90)
    plt.title(f"Круговая диаграмма для '{name}'")
    plt.ylabel('')
    plt.show()

# %%
data_market_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   покупательская_активность            1300 non-null   object
#  2   тип_сервиса                          1300 non-null   object
#  3   разрешить_сообщать                   1300 non-null   object
#  4   маркет_актив_6_мес                   1300 non-null   float64
#  5   маркет_актив_тек_мес                 1300 non-null   int64
#  6   длительность                         1300 non-null   int64
#  7   акционные_покупки                    1300 non-null   float64
#  8   популярная_категория                 1300 non-null   object
#  9   средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %%
plot_pie(data_market_file, "покупательская_активность")

# %% [markdown]
# **Можно сразу отметить дисбаланс классов в целевом признаке. Значений категории "прежний уровень" значительно больше чем "снизилась". Модель сможет с большой точностью определять мажорный класс, но для нашей бизнес задачи намного важнее определять покупателей чья активность снизилась. Возьмем на заметку**

# %%
plot_pie(data_market_file, "тип_сервиса")

# %% [markdown]
# Покупателей с сервисом стандарт значительно больше.

# %%
plot_pie(data_market_file, "разрешить_сообщать")

# %% [markdown]
# Почти 3к1 отношение пользователей, разрешивших присылать дополнительную информацию к запретившим. Такое соотношение довольно хорошее, но для нас было бы лучше уменьшить количество отказавших, так как если большинство клиентов из категории "нет" имеют сниженную активность, то мы лишаемся потенциальной возможности повысить их активность через удержание и привлечения. Можно это проверить

# %%
print(data_market_file.query("разрешить_сообщать == 'нет'")["id"].count())
# Out:
# 338

# %%
print(data_market_file.query("разрешить_сообщать == 'нет' and покупательская_активность == 'Снизилась'")["id"].count())
# Out:
# 127

# %%
print(f"Доля: {(127/338):.2f}")
# Out:
# Доля: 0.38

# %% [markdown]
# Доля пользователей со сниженной активностью составляет 38%. Если в будущем при новом наборе данных такое соотношение сохранится, то это тревожный звоночек для нашего бизнеса. Вне зависимости от того верно мы определяем пользователей со сниженной активностью или нет, мы лишаемся потенциальной возможности исправить ситуацию через присылаемую информацию. Тем не менее, остается способ через персональные реккомендации на сайте.

# %%
plot_pie(data_market_file, "популярная_категория")

# %% [markdown]
# * Самыми популярными категориями для покупок являются: Товары для детей(25.4%), Домашний текстиль(19.3%) и Косметика и аксесуары(17.2%)
# * Самыми непопулярными категориями для покупок являются: Кухонная посуда(10.6%), Мелкая бытовая техника и электроника(13.4%) и Техника для красоты и здоровья(14.2%)

# %%
plot_hist(data_market_file, "маркет_актив_6_мес", 10)
plot_box(data_market_file, "маркет_актив_6_мес", 0.5, 7)
data_market_file["маркет_актив_6_мес"].describe()
# Out:
# count    1300.000000
# mean        4.253769
# std         1.014814
# min         0.900000
# 25%         3.700000
# 50%         4.200000
# 75%         4.900000
# max         6.600000
# Name: маркет_актив_6_мес, dtype: float64

# %% [markdown]
# График для среднемесячного значение маркетинговых коммуникаций за 6 месяцев показывает, что медианное значение равно 4.2, когда максимальное и минимальное равны 6.6 и 0.9 соотвественно. Были обнаруженны выбросы, но их фактический смысл заключается в том, что не все пользователи взаимодействуют в рамках маркетинговых коммуникаций.

# %%
plot_hist(data_market_file, "маркет_актив_тек_мес", 3)
plot_box(data_market_file, "маркет_актив_тек_мес", 2, 6)
data_market_file["маркет_актив_тек_мес"].describe()
# Out:
# count    1300.000000
# mean        4.011538
# std         0.696868
# min         3.000000
# 25%         4.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: маркет_актив_тек_мес, dtype: float64

# %% [markdown]
# График количества маркетинговых коммуникаций за текущий месяц показывает, что медианное значение равно 4, когда максимальное и минимальное равны 5 и 3 соотвественно. Количество пользователей с 3 и 5 коммуникациями практически равны. Распределение близко к нормальному.

# %%
plot_hist(data_market_file, "длительность", 30)
plot_box(data_market_file, "длительность", 80, 1200)
data_market_file["длительность"].describe()
# Out:
# count    1300.000000
# mean      601.898462
# std       249.856289
# min       110.000000
# 25%       405.500000
# 50%       606.000000
# 75%       806.000000
# max      1079.000000
# Name: длительность, dtype: float64

# %% [markdown]
# Выбросов не наблюдается. График длительности показывает, что медианное значение равно 606 дням, когда максимальное и минимальное равны 1079 и 110 соотвественно. Примечательно, что у сайта давно не было новых пользователей, что совпадает с изначальным аргументом о том, что о сайте знает большая часть целевой аудитории.

# %%
plot_hist(data_market_file, "акционные_покупки", 10)
plot_box(data_market_file, "акционные_покупки", -0.5, 1.2)
data_market_file["акционные_покупки"].describe()
# Out:
# count    1300.000000
# mean        0.319808
# std         0.249843
# min         0.000000
# 25%         0.170000
# 50%         0.240000
# 75%         0.300000
# max         0.990000
# Name: акционные_покупки, dtype: float64

# %% [markdown]
# График среднемесячной доли покупок по акции за 6 месяцев показывавет, что медианное значение равно 0.24, когда максимальное и минимальное равны 0.99 и 0 соотвественно. Много выбросов расположилось у отметки близкие к 1. Другими словами, мы имеем много пользователей, которые в основном совершают покупки только по акционным предложениям.

# %%
print(data_market_file.query("акционные_покупки > 0.8")["id"].count())
# Out:
# 165

# %% [markdown]
# Их количество слишком большое, чтобы избавиться от них. В дополнении, эти данные не выбиваются из логики.

# %%
plot_hist(data_market_file, "средний_просмотр_категорий_за_визит", 6)
plot_box(data_market_file, "средний_просмотр_категорий_за_визит", 0, 7)
data_market_file["средний_просмотр_категорий_за_визит"].describe()
# Out:
# count    1300.00000
# mean        3.27000
# std         1.35535
# min         1.00000
# 25%         2.00000
# 50%         3.00000
# 75%         4.00000
# max         6.00000
# Name: средний_просмотр_категорий_за_визит, dtype: float64

# %% [markdown]
# График среднего просмотра категорий за визит в течении месяца показывавет, что медианное значение равно 3, когда максимальное и минимальное равны 6 и 1 соотвественно.

# %%
plot_hist(data_market_file, "неоплаченные_продукты_штук_квартал", 10)
plot_box(data_market_file, "неоплаченные_продукты_штук_квартал", -1, 11)
data_market_file["неоплаченные_продукты_штук_квартал"].describe()
# Out:
# count    1300.000000
# mean        2.840000
# std         1.971451
# min         0.000000
# 25%         1.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: неоплаченные_продукты_штук_квартал, dtype: float64

# %% [markdown]
# График общего числа неоплаченных товаров в корзине за последние 3 месяца показывавет, что медианное значение равно 3, когда максимальное и минимальное равны 0 и 10 соотвественно. Выбросы выше вверхнего уса на отметке 8 объяснимы, так как модель поведения пользователя, который закидывает в корзину все подряд встречается часто.

# %%
plot_hist(data_market_file, "ошибка_сервиса", 10)
plot_box(data_market_file, "ошибка_сервиса", -1, 11)
data_market_file["ошибка_сервиса"].describe()
# Out:
# count    1300.000000
# mean        4.185385
# std         1.955298
# min         0.000000
# 25%         3.000000
# 50%         4.000000
# 75%         6.000000
# max         9.000000
# Name: ошибка_сервиса, dtype: float64

# %% [markdown]
# График числа сбоев близок к нормальному распределению и показывает, что медианное значение равно 4, когда максимальное и минимальное равны 0 и 9 соотвественно.

# %%
plot_hist(data_market_file, "страниц_за_визит", 10)
plot_box(data_market_file, "страниц_за_визит", 0, 25)
data_market_file["страниц_за_визит"].describe()
# Out:
# count    1300.000000
# mean        8.176923
# std         3.978126
# min         1.000000
# 25%         5.000000
# 50%         8.000000
# 75%        11.000000
# max        20.000000
# Name: страниц_за_визит, dtype: float64

# %% [markdown]
# График среднего количество страниц(один визит) за 3 месяца, что медианное значение равно 8, когда максимальное и минимальное равны 20 и 1 соотвественно. Выбросов нет

# %% [markdown]
# **Промежуточный вывод по таблице market_file:**
# * Можно сразу отметить дисбаланс классов в целевом признаке. Значений категории "прежний уровень" значительно больше чем "снизилась". Модель сможет с большой точностью определять мажорный класс
# * Покупателей с сервисом стандарт значительно больше, что вполне объяснимо
# * Почти 3к1 отношение пользователей, разрешивших присылать дополнительную информацию к запретившим.
# * Самыми популярными категориями для покупок являются: Товары для детей(25.4%), Домашний текстиль(19.3%) и Косметика и аксесуары(17.2%)
# * Самыми непопулярными категориями для покупок являются: Кухонная посуда(10.6%), Мелкая бытовая техника и электроника(13.4%) и Техника для красоты и здоровья(14.2%)
# * График для среднемесячного значение маркетинговых коммуникаций за 6 месяцев показывает, что медианное значение равно 4.2, когда максимальное и минимальное равны 6.6 и 0.9 соотвественно. Были обнаруженны выбросы, но их фактический смысл заключается в том, что не все пользователи взаимодействуют в рамках маркетинговых коммуникаций.
# * График количества маркетинговых коммуникаций за текущий месяц показывает, что медианное значение равно 4, когда максимальное и минимальное равны 5 и 3 соотвественно.
# * График длительности показывает, что медианное значение равно 606 дням, когда максимальное и минимальное равны 1079 и 110 соотвественно. Примечательно, что у сайта давно не было новых пользователей, что совпадает с изначальным аргументом о том, что о сайте знает большая часть целевой аудитории.
# * График среднемесячной доли покупок по акции за 6 месяцев показывавет, что медианное значение равно 0.24, когда максимальное и минимальное равны 0.99 и 0 соотвественно. Много выбросов расположилось у отметки близкие к 1. Другими словами, мы имеем много пользователей, которые в основном совершают покупки только по акционным предложениям.
# * График среднего просмотра категорий за визит в течении месяца показывавет, что медианное значение равно 3, когда максимальное и минимальное равны 6 и 1 соотвественно.
# * График общего числа неоплаченных товаров в корзине за последние 3 месяца показывавет, что медианное значение равно 3, когда максимальное и минимальное равны 0 и 10 соотвественно.
# * График числа сбоев близок к нормальному распределению и показывает, что медианное значение равно 4, когда максимальное и минимальное равны 0 и 9 соотвественно.
# * График среднего количество страниц(один визит) за 3 месяца, что медианное значение равно 8, когда максимальное и минимальное равны 20 и 1 соотвественно.

# %%
data_market_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   период   3900 non-null   object
#  2   выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %%
plot_pie(data_market_money, "период")

# %% [markdown]
# Количество покупок между периодами одинаковы.

# %%
plot_hist(data_market_money, "выручка", 60, 0, 15000)
plot_box(data_market_money, "выручка", 0, 11000)
data_market_money["выручка"].describe()
# Out:
# count      3900.000000
# mean       5025.696051
# std        1777.704104
# min           0.000000
# 25%        4590.150000
# 50%        4957.500000
# 75%        5363.000000
# max      106862.200000
# Name: выручка, dtype: float64

# %% [markdown]
# График выручки за период показывает, что медианное значение равно 4957.5, когда максимальное и минимальное равны 106862.2 и 0 соотвественно. Выбросов присутствуют, но их наличие объяснимо. Дорогие покупки или наоборот отсутствие покупок за период обычное явление для сайта-магазина.

# %% [markdown]
# **Промежуточный вывод по таблице market_money:**
# * Количество покупок между периодами одинаковы.
# * График выручки за период показывает, что медианное значение равно 4957.5, когда максимальное и минимальное равны 106862.2 и 0 соотвественно. Выбросов присутствуют, но их наличие объяснимо.

# %%
data_market_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %%
plot_pie(data_market_time, "период")

# %% [markdown]
# Общее время, проведенное пользователями одинаковое в текущем и предыдущем месяце равны.

# %%
plot_hist(data_market_time, "минут", 10)
plot_box(data_market_time, "минут", 0, 25)
data_market_time["минут"].describe()
# Out:
# count    2600.000000
# mean       13.336154
# std         4.080198
# min         4.000000
# 25%        10.000000
# 50%        13.000000
# 75%        16.000000
# max        23.000000
# Name: минут, dtype: float64

# %% [markdown]
# График проведенного времени показывает, что медианное значение для обоих месяцев равно 13 минутам, когда максимальное и минимальное равны 23 и 4 минуты соотвественно.

# %% [markdown]
# **Промежуточный вывод по таблице market_time:**
# * Общее время, проведенное пользователями одинаковое в текущем и предыдущем месяце равны 13 минутам.
# * График проведенного времени показывает, что медианное значение для обоих месяцев равно 13 минутам, когда максимальное и минимальное равны 23 и 4 минуты соотвественно.

# %%
data_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %%
plot_hist(data_money, "прибыль", 10)
plot_box(data_money, "прибыль", 0, 8)
data_money["прибыль"].describe()
# Out:
# count    1300.000000
# mean        3.996631
# std         1.013722
# min         0.860000
# 25%         3.300000
# 50%         4.045000
# 75%         4.670000
# max         7.430000
# Name: прибыль, dtype: float64

# %% [markdown]
# График о среднемесячной прибыли покупателя за последние 3 месяца показывает, что медианное значение равно 4.045, когда максимальное и минимальное равны 7.43 и 0.86 минуты соотвественно. Выбросы объяснимы, так как покупки пользователей не всегда стабильны от месяца к месяцу, поэтому прибыль магазина варьируется.

# %%
active_user = data_money.query("прибыль != 0")

# %%
active_user = data_market_file[data_market_file["id"].isin(active_user["id"])]

# %%
display(active_user)
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0     215348                 Снизилась     премиум                 да
# 1     215349                 Снизилась     премиум                 да
# 2     215350                 Снизилась    стандарт                нет
# 3     215351                 Снизилась    стандарт                 да
# 4     215352                 Снизилась    стандарт                нет
# ...      ...                       ...         ...                ...
# 1295  216643           Прежний уровень    стандарт                 да
# 1296  216644           Прежний уровень    стандарт                нет
# 1297  216645           Прежний уровень    стандарт                 да
# 1298  216646           Прежний уровень    стандарт                 да
# 1299  216647           Прежний уровень     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 0                    3.4                     5           121
# ...

# %% [markdown]
# **Мы получили информацию о клиентах с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период**

# %% [markdown]
# **Итоги по исследовательскому анализу данных:**
# * Можно сразу отметить дисбаланс классов в целевом признаке. Значений категории "прежний уровень" значительно больше чем "снизилась". Модель сможет с большой точностью определять мажорный класс
# * Покупателей с сервисом стандарт значительно больше, что вполне объяснимо
# * Почти 3к1 отношение пользователей, разрешивших присылать дополнительную информацию к запретившим.
# * Самыми популярными категориями для покупок являются: Товары для детей(25.4%), Домашний текстиль(19.3%) и Косметика и аксесуары(17.2%)
# * Самыми непопулярными категориями для покупок являются: Кухонная посуда(10.6%), Мелкая бытовая техника и электроника(13.4%) и Техника для красоты и здоровья(14.2%)
# * График для среднемесячного значение маркетинговых коммуникаций за 6 месяцев показывает, что медианное значение равно 4.2, когда максимальное и минимальное равны 6.6 и 0.9 соотвественно. Были обнаруженны выбросы, но их фактический смысл заключается в том, что не все пользователи взаимодействуют в рамках маркетинговых коммуникаций.
# * График длительности показывает, что медианное значение равно 606 дням, когда максимальное и минимальное равны 1079 и 110 соотвественно. Примечательно, что у сайта давно не было новых пользователей, что совпадает с изначальным аргументом о том, что о сайте знает большая часть целевой аудитории.
# * График среднемесячной доли покупок по акции за 6 месяцев показывавет, что медианное значение равно 0.24, когда максимальное и минимальное равны 0.99 и 0 соотвественно. Много выбросов расположилось у отметки близкие к 1. Другими словами, мы имеем много пользователей, которые в основном совершают покупки только по акционным предложениям.
# * График выручки за период показывает, что медианное значение равно 4957.5, когда максимальное и минимальное равны 106862.2 и 0 соотвественно.
# * Количество покупок между периодами одинаковы.
# * Общее время, проведенное пользователями одинаковое в текущем и предыдущем месяце равны 13 минутам.
# * График о среднемесячной прибыли покупателя за последние 3 месяца показывает, что медианное значение равно 4.045, когда максимальное и минимальное равны 7.43 и 0.86 минуты соотвественно
# * Мы получили информацию о клиентах с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период

# %% [markdown]
# ## Объединение таблиц
# <a id="объединение"></a>

# %%
display(data_market_money)
# Out:
#           id               период  выручка
# 0     215348  препредыдущий_месяц      0.0
# 1     215348        текущий_месяц   3293.1
# 2     215348     предыдущий_месяц      0.0
# 3     215349  препредыдущий_месяц   4472.0
# 4     215349        текущий_месяц   4971.6
# ...      ...                  ...      ...
# 3895  216646  препредыдущий_месяц   4725.0
# 3896  216646     предыдущий_месяц   4923.0
# 3897  216647     предыдущий_месяц   4720.0
# 3898  216647  препредыдущий_месяц   5183.0
# 3899  216647        текущий_месяц   4448.3
#
# [3900 rows x 3 columns]

# %%
data_market_money_pivot = data_market_money.pivot(index = "id", columns = "период", values = "выручка").reset_index()

# %%
data_market_money_pivot = data_market_money_pivot.rename(columns={
    'текущий_месяц': 'выручка_текущий_месяц',
    'предыдущий_месяц': 'выручка_предыдущий_месяц',
    'препредыдущий_месяц': 'выручка_препредыдущий_месяц'
})

# %%
display(data_market_money_pivot)
# Out:
# период      id  выручка_предыдущий_месяц  выручка_препредыдущий_месяц  \
# 0       215348                       0.0                          0.0
# 1       215349                    5216.0                       4472.0
# 2       215350                    5457.5                       4826.0
# 3       215351                    6158.0                       4793.0
# 4       215352                    5807.5                       4594.0
# ...        ...                       ...                          ...
# 1295    216643                    3664.0                       4704.0
# 1296    216644                    4729.0                       5299.0
# 1297    216645                    5160.0                       5334.0
# 1298    216646                    4923.0                       4725.0
# 1299    216647                    4720.0                       5183.0
#
# период  выручка_текущий_месяц
# 0                      3293.1
# 1                      4971.6
# 2                      5058.4
# ...

# %%
display(data_market_time)
# Out:
#           id            период  минут
# 0     215348     текущий_месяц     14
# 1     215348  предыдущий_месяц     13
# 2     215349     текущий_месяц     10
# 3     215349  предыдущий_месяц     12
# 4     215350     текущий_месяц     13
# ...      ...               ...    ...
# 2595  216645     текущий_месяц     18
# 2596  216646  предыдущий_месяц     18
# 2597  216646     текущий_месяц      7
# 2598  216647     текущий_месяц     10
# 2599  216647  предыдущий_месяц     15
#
# [2600 rows x 3 columns]

# %%
data_market_time_pivot = data_market_time.pivot(index = "id", columns = "период", values = "минут").reset_index()

# %%
data_market_time_pivot = data_market_time_pivot.rename(columns={
    'текущий_месяц': 'минут_текущий_месяц',
    'предыдущий_месяц': 'минут_предыдущий_месяц'
})

# %%
display(data_market_time_pivot)
# Out:
# период      id  минут_предыдущий_месяц  минут_текущий_месяц
# 0       215348                      13                   14
# 1       215349                      12                   10
# 2       215350                       8                   13
# 3       215351                      11                   13
# 4       215352                       8                   11
# ...        ...                     ...                  ...
# 1295    216643                      14                    7
# 1296    216644                      12                   11
# 1297    216645                      12                   18
# 1298    216646                      18                    7
# 1299    216647                      15                   10
#
# [1300 rows x 3 columns]

# %%
merge_time_money = data_market_money_pivot.merge(data_market_time_pivot, on='id', how='inner')

# %%
display(merge_time_money)
# Out:
# период      id  выручка_предыдущий_месяц  выручка_препредыдущий_месяц  \
# 0       215348                       0.0                          0.0
# 1       215349                    5216.0                       4472.0
# 2       215350                    5457.5                       4826.0
# 3       215351                    6158.0                       4793.0
# 4       215352                    5807.5                       4594.0
# ...        ...                       ...                          ...
# 1295    216643                    3664.0                       4704.0
# 1296    216644                    4729.0                       5299.0
# 1297    216645                    5160.0                       5334.0
# 1298    216646                    4923.0                       4725.0
# 1299    216647                    4720.0                       5183.0
#
# период  выручка_текущий_месяц  минут_предыдущий_месяц  минут_текущий_месяц
# ...

# %%
merge_time_money.shape
# Out:
# (1300, 6)

# %%
display(data_market_file)
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0     215348                 Снизилась     премиум                 да
# 1     215349                 Снизилась     премиум                 да
# 2     215350                 Снизилась    стандарт                нет
# 3     215351                 Снизилась    стандарт                 да
# 4     215352                 Снизилась    стандарт                нет
# ...      ...                       ...         ...                ...
# 1295  216643           Прежний уровень    стандарт                 да
# 1296  216644           Прежний уровень    стандарт                нет
# 1297  216645           Прежний уровень    стандарт                 да
# 1298  216646           Прежний уровень    стандарт                 да
# 1299  216647           Прежний уровень     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 0                    3.4                     5           121
# ...

# %%
data_merge = data_market_file.merge(merge_time_money, on='id', how='inner')

# %%
display(data_merge)
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0     215348                 Снизилась     премиум                 да
# 1     215349                 Снизилась     премиум                 да
# 2     215350                 Снизилась    стандарт                нет
# 3     215351                 Снизилась    стандарт                 да
# 4     215352                 Снизилась    стандарт                нет
# ...      ...                       ...         ...                ...
# 1295  216643           Прежний уровень    стандарт                 да
# 1296  216644           Прежний уровень    стандарт                нет
# 1297  216645           Прежний уровень    стандарт                 да
# 1298  216646           Прежний уровень    стандарт                 да
# 1299  216647           Прежний уровень     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 0                    3.4                     5           121
# ...

# %%
data_merge.shape
# Out:
# (1300, 18)

# %%
data_merge["выручка_текущий_месяц"].describe()
# Out:
# count      1300.000000
# mean       5314.960846
# std        2939.708156
# min        2758.700000
# 25%        4706.050000
# 50%        5179.950000
# 75%        5761.725000
# max      106862.200000
# Name: выручка_текущий_месяц, dtype: float64

# %% [raw]
# data_merge["выручка_текущий_месяц"].sort_values(ascending = False)

# %%
data_merge = data_merge[data_merge["выручка_текущий_месяц"] != 106862.2]

# %%
data_merge["выручка_текущий_месяц"].sort_values(ascending = False)
# Out:
# 145     7799.4
# 87      7605.3
# 493     7557.0
# 796     7547.8
# 188     7467.9
#          ...
# 1094    3085.4
# 212     3083.7
# 130     3078.3
# 828     2952.2
# 118     2758.7
# Name: выручка_текущий_месяц, Length: 1299, dtype: float64

# %% [markdown]
# Мы можем заметить аномально большое значение в выручке за текущий месяц. Такое значение только одно, поэтому можно посчитать за выброс и удалить его.

# %%
data_merge.shape
# Out:
# (1299, 18)

# %%
active_user.shape
# Out:
# (1300, 13)

# %%
data_merge = data_merge[data_merge["id"].isin(active_user["id"])]

# %%
data_merge.shape
# Out:
# (1299, 18)

# %%
display(data_merge)
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0     215348                 Снизилась     премиум                 да
# 1     215349                 Снизилась     премиум                 да
# 2     215350                 Снизилась    стандарт                нет
# 3     215351                 Снизилась    стандарт                 да
# 4     215352                 Снизилась    стандарт                нет
# ...      ...                       ...         ...                ...
# 1295  216643           Прежний уровень    стандарт                 да
# 1296  216644           Прежний уровень    стандарт                нет
# 1297  216645           Прежний уровень    стандарт                 да
# 1298  216646           Прежний уровень    стандарт                 да
# 1299  216647           Прежний уровень     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 0                    3.4                     5           121
# ...

# %%
data_merge["выручка_предыдущий_месяц"].sort_values(ascending = True)
# Out:
# 0         0.0
# 9         0.0
# 11        0.0
# 216    2890.0
# 220    2909.0
#         ...
# 153    6604.0
# 210    6658.5
# 145    6716.5
# 23     6809.0
# 87     6869.5
# Name: выручка_предыдущий_месяц, Length: 1299, dtype: float64

# %%
data_merge = data_merge.query("выручка_предыдущий_месяц != 0")

# %%
display(data_merge)
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 1     215349                 Снизилась     премиум                 да
# 2     215350                 Снизилась    стандарт                нет
# 3     215351                 Снизилась    стандарт                 да
# 4     215352                 Снизилась    стандарт                нет
# 5     215353                 Снизилась    стандарт                 да
# ...      ...                       ...         ...                ...
# 1295  216643           Прежний уровень    стандарт                 да
# 1296  216644           Прежний уровень    стандарт                нет
# 1297  216645           Прежний уровень    стандарт                 да
# 1298  216646           Прежний уровень    стандарт                 да
# 1299  216647           Прежний уровень     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 1                    4.4                     4           819
# ...

# %% [markdown]
# Теперь мы получили информацию только о тех пользователей, которые проявляли активность хотя бы в одном из 3 месяцев. Причиной для этого является то, что для анализа по целевому признаку нужно учитывать только данные об актуальных и активных пользователей. Данные о неактивных пользователей только добавят лишнего шума в нашу модель.

# %% [markdown]
# **Итоги по объединению таблиц**
# * Мы объединили таблицы market_file.csv, market_money.csv и market_time.csv
# * В итоговой таблице присутствуют столбцы, содержащие информацию о выручке и времени за каждый период
# * Мы получили информацию только о тех пользователей, которые проявляли активность хотя бы в одном из 3 месяцев

# %% [markdown]
# ## Корреляционный анализ
# <a id="корреляция"></a>

# %% [markdown]
# Проведите корреляционный анализ признаков в количественной шкале в итоговой таблице для моделирования. Сделайте выводы о мультиколлинеарности и при необходимости устраните её.

# %%
num_cols = []

# %%
for col in data_merge.columns:
    if ((data_merge[col].dtype == 'int64' or data_merge[col].dtype == 'float64') and (col != 'id')):
        num_cols.append(col)

# %%
print(num_cols)
# Out:
# ['маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность', 'акционные_покупки', 'средний_просмотр_категорий_за_визит', 'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса', 'страниц_за_визит', 'выручка_предыдущий_месяц', 'выручка_препредыдущий_месяц', 'выручка_текущий_месяц', 'минут_предыдущий_месяц', 'минут_текущий_месяц']

# %%
phik_overview = phik_matrix(data_merge[num_cols], interval_cols = num_cols)

# %%
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title=r'correlation $\phi_K$',
    fontsize_factor=1.5,
    figsize=(20, 15)
)

# %% [markdown]
# Корреляционный анализ показывает, что между признаками нет корреляции, приближенной к 1. Можно сделать вывод, что в нашем случае утечек данных нет. Несмотря на довольно сильную связь между выручкой за препредыдущий месяц и выручкой за предыдущий месяц, акционные покупки, а также сильную связь между выручками за прошедшие месяца - можно сказать, что признаков мультиколлинеарности не наблюдается. Это объясняется тем, что коэффициент не превышает значение - 0.8.

# %% [markdown]
# **Итоги по корреляционному анализу признаков:**
# * Утечки данных и признаки мультиколлинеарности отсутствуют.

# %% [markdown]
# ## Использование пайплайнов
# <a id="пайплайн"></a>

# %%
display(data_merge)
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 1     215349                 Снизилась     премиум                 да
# 2     215350                 Снизилась    стандарт                нет
# 3     215351                 Снизилась    стандарт                 да
# 4     215352                 Снизилась    стандарт                нет
# 5     215353                 Снизилась    стандарт                 да
# ...      ...                       ...         ...                ...
# 1295  216643           Прежний уровень    стандарт                 да
# 1296  216644           Прежний уровень    стандарт                нет
# 1297  216645           Прежний уровень    стандарт                 да
# 1298  216646           Прежний уровень    стандарт                 да
# 1299  216647           Прежний уровень     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 1                    4.4                     4           819
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(
    data_merge.drop(['id','покупательская_активность'], axis=1),
    data_merge['покупательская_активность'],
    test_size = 0.25, 
    random_state = RANDOM_STATE,
    stratify = data_merge['покупательская_активность']
)

# %%
X_train.shape, X_test.shape
# Out:
# ((972, 16), (324, 16))

# %%
y_train.value_counts()
# Out:
# Прежний уровень    601
# Снизилась          371
# Name: покупательская_активность, dtype: int64

# %% [markdown]
# **Как было выявленно раньше, мы имеем явный дизбаланс классов, поэтому лучшей метрикой для нашего случая будет являться ROC-AUC, так как она способна разделять классы вне зависимости от самого баланса классов и нечувствительна к порогам**

# %%
ohe_columns = ['разрешить_сообщать', 'популярная_категория']
ord_columns = ['тип_сервиса']
num_columns = ['маркет_актив_6_мес', 'маркет_актив_тек_мес',
               'длительность', 'акционные_покупки', 'средний_просмотр_категорий_за_визит',
               'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса', 'страниц_за_визит',
               'выручка_предыдущий_месяц', 'выручка_препредыдущий_месяц', 'выручка_текущий_месяц',
               'минут_предыдущий_месяц', 'минут_текущий_месяц'
              ]

# %%
ohe_pipe = Pipeline(
    [
        ('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
        ('ohe', OneHotEncoder(drop='first', handle_unknown='error', sparse_output=False))
    ]
)

# %%
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',OrdinalEncoder(
                categories=[
                    ['премиум', 'стандарт']
                ], 
                handle_unknown = 'use_encoded_value', unknown_value = np.nan
            )
        ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# %%
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %%
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

# %%
param_grid = [
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 10), 
        'models__max_features': range(2, 5), 
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },

    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 5),         
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },
    
    {
        'models': [SVC(random_state = RANDOM_STATE)],
        'models__C': [0.1, 1, 10, 100],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  

    },

    {
        'models': [LogisticRegression(random_state=RANDOM_STATE)],
        'models__C': [0.01, 0.1, 1, 10, 100],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    }
]

# %%
randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring='roc_auc',
    random_state=RANDOM_STATE,
    n_jobs=-1
)

# %%
l = LabelEncoder()
y_train = l.fit_transform(y_train)
y_test = l.transform(y_test)

# %%
print(f"0: {l.classes_[0]}")
print(f"1: {l.classes_[1]}")
# Out:
# 0: Прежний уровень
# 1: Снизилась

# %% [markdown]
# **Теперь мы знаем, что класс 0 соответствует категории прежний уровень, а класс 1 категории снизилась**

# %%
randomized_search.fit(X_train, y_train)
# Out:
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print ('Метрика лучшей модели на тренировочной выборке:', randomized_search.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse_output=False))]),
#                                                   ['разрешить_сообщать',
#                                                    'популярная_категория']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('simpleImputer_before_ord',
# ...

# %%
y_test_proba = randomized_search.predict_proba(X_test)[:, 1]

# %%
y_test_pred = randomized_search.predict(X_test)
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test, y_test_proba)}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.8965740403672694

# %% [markdown]
# **Итоги по использованию пайплайнов:**
# * Лучшей моделью оказалась LogisticRegression с гиперпараметром C=0.01
# * Метрика лучшей модели на тренировочной выборке: 0.8762585163676073
# * Метрика ROC-AUC на тестовой выборке: 0.8904670197400097

# %% [markdown]
# ## Анализ важности признаков
# <a id="важность"></a>

# %%
best_pipeline = randomized_search.best_estimator_
preprocessor = best_pipeline.named_steps['preprocessor']
model = best_pipeline.named_steps['models']

# %%
X_train_preprocessed = preprocessor.transform(X_train)
X_test_preprocessed = preprocessor.transform(X_test)

# %%
ohe_features = preprocessor.named_transformers_['ohe'].named_steps['ohe'].get_feature_names_out(ohe_columns)
ord_features = ord_columns
num_features = num_columns
feature_names = best_pipeline.named_steps['preprocessor'].get_feature_names_out()

# %%
X_test_preprocessed_df = pd.DataFrame(X_test_preprocessed, columns=feature_names)

# %%
explainer = shap.LinearExplainer(model, X_train_preprocessed, feature_names=feature_names)
shap_values = explainer.shap_values(X_test_preprocessed)
shap.summary_plot(
    shap_values, 
    X_test_preprocessed, 
    feature_names=feature_names,
    plot_size=(12, 8)
)

# %% [markdown]
# **Итоги по анализу важности остатков:**
# * Самыми важными признаками оказались: страницы_за_визит, неоплаченные_продукты_штук_квартал, минут_текущий_месяц и минут_предыдущий_месяц
# * Высокие значения страницы_за_визит чаще смещают предсказание модели в сторону класса "прежний уровень" (класс 0). Пользователи, которые просматривают много страниц за визит, реже относятся к классу "снизилась"
# * Высокие значения неоплаченные_продукты_штук_квартал смещают предсказание влево, к классу "снизилась" (класс 1). Пользователи с большим количеством неоплаченных товаров в корзине чаще показывают снижение активности.
# * Увеличение времени на сайте (минут_текущий_месяц и минут_предыдущий_месяц) приводит к смещению предсказания к классу "прежний уровень" (класс 0). То есть пользователи, которые проводят больше времени на сайте, реже демонстрируют снижение активности.
# * Чем больше категорий просматривает пользователь (средний_просмотр_категорий_за_визит), тем выше вероятность, что активность не снизилась (класс 0).
# * Низкие значения выручки чаще смещают предсказание влево к классу "снизилась" (класс 1). Пользователи с низкими показателями выручки более склонны к снижению активности.

# %% [markdown]
# **Если честно, то изначально у меня была другая модель с более высокими показателями(K-neigh..), но у меня не получилось сделать для него график. Спустя 2 часа я просто решил подкрутить гиперпараметры, чтобы появилась возможность сделать график для более простой модели. Буду рад, если вы поделитесь способом визуализации.**

# %% [markdown]
# ## Сегментация покупателей
# <a id="сегментация"></a>

# %% [markdown]
# Можно выбрать группу клиентов, которые покупают только технику, то есть товары с длинным жизненным циклом и предположить как можно увеличить ее покупательскую активность.

# %%
display(data_merge)
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 1     215349                 Снизилась     премиум                 да
# 2     215350                 Снизилась    стандарт                нет
# 3     215351                 Снизилась    стандарт                 да
# 4     215352                 Снизилась    стандарт                нет
# 5     215353                 Снизилась    стандарт                 да
# ...      ...                       ...         ...                ...
# 1295  216643           Прежний уровень    стандарт                 да
# 1296  216644           Прежний уровень    стандарт                нет
# 1297  216645           Прежний уровень    стандарт                 да
# 1298  216646           Прежний уровень    стандарт                 да
# 1299  216647           Прежний уровень     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 1                    4.4                     4           819
# ...

# %%
display(data_merge["популярная_категория"].unique())
# Out:
# array(['Товары для детей', 'Домашний текстиль', 'Косметика и аксесуары',
#        'Кухонная посуда', 'Техника для красоты и здоровья',
#        'Мелкая бытовая техника и электроника'], dtype=object)

# %% [markdown]
# **Мы выделим 2 такие категории: Техника для красоты и здоровья и Мелкая бытовая техника и электроника**

# %%
result = pd.crosstab(data_merge['популярная_категория'], data_merge['покупательская_активность'])
result = result.loc[['Техника для красоты и здоровья', 'Мелкая бытовая техника и электроника']]

# %%
display(result)
# Out:
# покупательская_активность             Прежний уровень  Снизилась
# популярная_категория
# Техника для красоты и здоровья                    132         50
# Мелкая бытовая техника и электроника              147         27

# %%
result.plot(kind='bar', figsize=(8, 6))
plt.title('Распределение покупательской активности по выбранным категориям')
plt.xlabel('Популярная категория')
plt.ylabel('Количество')
plt.legend(title='Покупательская активность')
plt.show()

# %%
result.describe()
# Out:
# покупательская_активность  Прежний уровень  Снизилась
# count                             2.000000   2.000000
# mean                            139.500000  38.500000
# std                              10.606602  16.263456
# min                             132.000000  27.000000
# 25%                             135.750000  32.750000
# 50%                             139.500000  38.500000
# 75%                             143.250000  44.250000
# max                             147.000000  50.000000

# %% [markdown]
# Мы видим, что категория техника для красоты и здоровья популярнее чем мелкая бытовая техника. Тем не менее, наибольшой показатель сниженной активности наблюдается как раз у первой категории.

# %% [markdown]
# Попробуем оценить по значению прибыли

# %%
data_with_profit = data_merge.merge(data_money, on='id', how='inner')

# %%
display(data_with_profit)
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0     215349                 Снизилась     премиум                 да
# 1     215350                 Снизилась    стандарт                нет
# 2     215351                 Снизилась    стандарт                 да
# 3     215352                 Снизилась    стандарт                нет
# 4     215353                 Снизилась    стандарт                 да
# ...      ...                       ...         ...                ...
# 1291  216643           Прежний уровень    стандарт                 да
# 1292  216644           Прежний уровень    стандарт                нет
# 1293  216645           Прежний уровень    стандарт                 да
# 1294  216646           Прежний уровень    стандарт                 да
# 1295  216647           Прежний уровень     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 0                    4.4                     4           819
# ...

# %%
filtered_data = data_with_profit[data_with_profit['популярная_категория'].isin([
'Техника для красоты и здоровья', 'Мелкая бытовая техника и электроника'
])]

# %%
profit_summary = filtered_data.groupby(['популярная_категория', 'покупательская_активность'])['прибыль'].mean().reset_index()

# %%
print(profit_summary)
# Out:
#                    популярная_категория покупательская_активность   прибыль
# 0  Мелкая бытовая техника и электроника           Прежний уровень  3.931020
# 1  Мелкая бытовая техника и электроника                 Снизилась  3.978519
# 2        Техника для красоты и здоровья           Прежний уровень  3.742500
# 3        Техника для красоты и здоровья                 Снизилась  3.928600

# %% [markdown]
# Прибыль они приносят примерно одинаковую, но мелкая бытовая техника и электроника все же вырываются вперед.

# %%
top_profit = filtered_data.groupby(['популярная_категория', 'id'])['прибыль'].sum().reset_index()

# %%
top_tech_beauty = top_profit[top_profit['популярная_категория'] == 'Техника для красоты и здоровья'] \
                    .sort_values(by='прибыль', ascending=False).head(10)

# %%
top_electronics = top_profit[top_profit['популярная_категория'] == 'Мелкая бытовая техника и электроника'] \
                    .sort_values(by='прибыль', ascending=False).head(10)

# %%
display(top_tech_beauty)
# Out:
#                популярная_категория      id  прибыль
# 334  Техника для красоты и здоровья  216533     6.59
# 176  Техника для красоты и здоровья  215368     6.27
# 209  Техника для красоты и здоровья  215749     6.17
# 306  Техника для красоты и здоровья  216336     6.09
# 197  Техника для красоты и здоровья  215613     5.99
# 222  Техника для красоты и здоровья  215837     5.95
# 293  Техника для красоты и здоровья  216276     5.75
# 213  Техника для красоты и здоровья  215768     5.61
# 278  Техника для красоты и здоровья  216196     5.56
# 212  Техника для красоты и здоровья  215760     5.49

# %%
display(top_electronics)
# Out:
#                      популярная_категория      id  прибыль
# 56   Мелкая бытовая техника и электроника  215985     6.78
# 132  Мелкая бытовая техника и электроника  216417     6.40
# 100  Мелкая бытовая техника и электроника  216186     6.29
# 94   Мелкая бытовая техника и электроника  216160     6.16
# 144  Мелкая бытовая техника и электроника  216467     5.87
# 109  Мелкая бытовая техника и электроника  216240     5.72
# 42   Мелкая бытовая техника и электроника  215894     5.64
# 173  Мелкая бытовая техника и электроника  216642     5.63
# 96   Мелкая бытовая техника и электроника  216169     5.61
# 102  Мелкая бытовая техника и электроника  216201     5.56

# %%
display(data_merge.query("id == 216533 or id == 215985"))
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 637   215985           Прежний уровень    стандарт                 да
# 1185  216533           Прежний уровень    стандарт                нет
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 637                  5.5                     5           541
# 1185                 5.7                     5           769
#
#       акционные_покупки                  популярная_категория  \
# 637                0.17  Мелкая бытовая техника и электроника
# 1185               0.14        Техника для красоты и здоровья
#
#       средний_просмотр_категорий_за_визит  неоплаченные_продукты_штук_квартал  \
# 637                                     4                                   1
# 1185                                    4                                   1
#
#       ошибка_сервиса  страниц_за_визит  выручка_предыдущий_месяц  \
# 637                6                 5                    5388.0
# ...

# %%
low_tech_beauty = top_profit[top_profit['популярная_категория'] == 'Техника для красоты и здоровья'] \
                    .sort_values(by='прибыль', ascending=False).tail(10)

# %%
low_electronics = top_profit[top_profit['популярная_категория'] == 'Мелкая бытовая техника и электроника'] \
                    .sort_values(by='прибыль', ascending=False).tail(10)

# %%
display(low_tech_beauty)
# Out:
#                популярная_категория      id  прибыль
# 328  Техника для красоты и здоровья  216484     2.08
# 340  Техника для красоты и здоровья  216570     2.07
# 251  Техника для красоты и здоровья  215992     2.07
# 265  Техника для красоты и здоровья  216076     2.00
# 262  Техника для красоты и здоровья  216059     1.84
# 330  Техника для красоты и здоровья  216492     1.68
# 314  Техника для красоты и здоровья  216399     1.57
# 217  Техника для красоты и здоровья  215786     1.55
# 296  Техника для красоты и здоровья  216286     1.08
# 272  Техника для красоты и здоровья  216122     0.86

# %%
display(low_electronics)
# Out:
#                      популярная_категория      id  прибыль
# 58   Мелкая бытовая техника и электроника  215996     2.13
# 167  Мелкая бытовая техника и электроника  216605     2.11
# 143  Мелкая бытовая техника и электроника  216465     2.03
# 137  Мелкая бытовая техника и электроника  216441     1.87
# 61   Мелкая бытовая техника и электроника  216016     1.68
# 55   Мелкая бытовая техника и электроника  215975     1.64
# 76   Мелкая бытовая техника и электроника  216080     1.64
# 141  Мелкая бытовая техника и электроника  216457     1.54
# 21   Мелкая бытовая техника и электроника  215775     1.38
# 117  Мелкая бытовая техника и электроника  216324     0.86

# %%
display(data_merge.query("id == 216324 or id == 216122"))
# Out:
#          id покупательская_активность тип_сервиса разрешить_сообщать  \
# 774  216122           Прежний уровень    стандарт                 да
# 976  216324           Прежний уровень     премиум                 да
#
#      маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 774                 5.8                     5           365
# 976                 4.3                     5           509
#
#      акционные_покупки                  популярная_категория  \
# 774               0.17        Техника для красоты и здоровья
# 976               0.25  Мелкая бытовая техника и электроника
#
#      средний_просмотр_категорий_за_визит  неоплаченные_продукты_штук_квартал  \
# 774                                    6                                   2
# 976                                    3                                   5
#
#      ошибка_сервиса  страниц_за_визит  выручка_предыдущий_месяц  \
# 774               4                 8                    4593.0
# ...

# %% [markdown]
# Если сравнить лидеров своих категорий и наоборот тех, кто расположился внизу по признакам из лучшей модели, то можно сделать закономерные выводы:
# * Количество страниц за визит и время, проведенное на сайте практически не отличается
# * Важным отличием является именно количество неоплаченных продуктов в корзине, у лидеров такое количество намного меньше - 1 против 5.

# %% [markdown]
# **Итоги по сегментации покупателей:**
# * Категория техника для красоты и здоровья популярнее чем мелкая бытовая техника. Тем не менее, наибольшой показатель сниженной активности наблюдается как раз у первой категории.
# * Прибыль они приносят примерно одинаковую, но мелкая бытовая техника и электроника все же вырываются вперед.
# * Количество страниц за визит и время, проведенное на сайте практически не отличается
# * Наибольшее влияние на данный сегмент оказывает именно количество неоплачченых продуктов.

# %% [markdown]
# **Рекомендации:**
# Нужно усилить маркетинговые усилия для удержания клиентов. Возможно выбор у категорий слишком большой или много похожих товаров, что пользователь добавляет все и потом не может решить что лучше. Другая причина может заключаться в том, что пользователь забывает о своих товарах в корзине или нашел более выгодное предложение. Я предлагаю внедрить напоминание о товарах в корзине через определенное время после завершения сеанса, а также персонализировать предложения, чтобы уменьшить выборку для пользователя.

# %% [markdown]
# ## Итоговые выводы
# <a id="выводы"></a>

# %% [markdown]
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.
# «В один клик» — современная компания, поэтому её руководство не хочет принимать решения просто так — только на основе анализа данных и бизнес-моделирования. У компании есть небольшой отдел цифровых технологий, и вам предстоит побыть в роли стажёра в этом отделе.
# Итак, вашему отделу поручили разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.

# %% [markdown]
# 1. Нужно построить модель, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца.
# 2. В исследование нужно включить дополнительные данные финансового департамента о прибыльности клиента: какой доход каждый покупатель приносил компании за последние три месяца.
# 3. Используя данные модели и данные о прибыльности клиентов, нужно выделить сегменты покупателей и разработать для них персонализированные предложения.

# %% [markdown]
# **Итоги по обзору данных:**
# * Пропуски отсутствуют
# * Неправильный тип данных у Маркет_актив_6_мес, акционные покупки, Средний_просмотр_категорий_за_визит и Выручка
# * Есть проблемы с названиями столбцов, нужно привести в змеиный регистр
# * Данные в столбце market_time (период) содержат опечатку.

# %% [markdown]
# **Итоги предобработки данных:**
#
# * Названия столбцов приведены к корректному формату (змеиный регистр).
# * Пропусков в данных нет
# * Явных дубликатов в данных нет
# * Неявные дубликаты и опечатки в данных были устранены
# * Неправильный тип данных у столбцов был изменен на корректный

# %% [markdown]
# **Итоги по исследовательскому анализу данных:**
# * Можно сразу отметить дисбаланс классов в целевом признаке. Значений категории "прежний уровень" значительно больше чем "снизилась". Модель сможет с большой точностью определять мажорный класс
# * Покупателей с сервисом стандарт значительно больше, что вполне объяснимо
# * Почти 3к1 отношение пользователей, разрешивших присылать дополнительную информацию к запретившим.
# * Самыми популярными категориями для покупок являются: Товары для детей(25.4%), Домашний текстиль(19.3%) и Косметика и аксесуары(17.2%)
# * Самыми непопулярными категориями для покупок являются: Кухонная посуда(10.6%), Мелкая бытовая техника и электроника(13.4%) и Техника для красоты и здоровья(14.2%)
# * График для среднемесячного значение маркетинговых коммуникаций за 6 месяцев показывает, что медианное значение равно 4.2, когда максимальное и минимальное равны 6.6 и 0.9 соотвественно. Были обнаруженны выбросы, но их фактический смысл заключается в том, что не все пользователи взаимодействуют в рамках маркетинговых коммуникаций.
# * График длительности показывает, что медианное значение равно 606 дням, когда максимальное и минимальное равны 1079 и 110 соотвественно. Примечательно, что у сайта давно не было новых пользователей, что совпадает с изначальным аргументом о том, что о сайте знает большая часть целевой аудитории.
# * График среднемесячной доли покупок по акции за 6 месяцев показывавет, что медианное значение равно 0.24, когда максимальное и минимальное равны 0.99 и 0 соотвественно. Много выбросов расположилось у отметки близкие к 1. Другими словами, мы имеем много пользователей, которые в основном совершают покупки только по акционным предложениям.
# * График выручки за период показывает, что медианное значение равно 4957.5, когда максимальное и минимальное равны 106862.2 и 0 соотвественно.
# * Количество покупок между периодами одинаковы.
# * Общее время, проведенное пользователями одинаковое в текущем и предыдущем месяце равны 13 минутам.
# * График о среднемесячной прибыли покупателя за последние 3 месяца показывает, что медианное значение равно 4.045, когда максимальное и минимальное равны 7.43 и 0.86 минуты соотвественно
# * Мы получили информацию о клиентах с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период

# %% [markdown]
# **Итоги по объединению таблиц**
# * Мы объединили таблицы market_file.csv, market_money.csv и market_time.csv
# * В итоговой таблице присутствуют столбцы, содержащие информацию о выручку и времени за каждый период

# %% [markdown]
# **Итоги по корреляционному анализу признаков:**
# * Утечки данных и признаки мультиколлинеарности отсутствуют.

# %%
display(active_user)
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0     215348                 Снизилась     премиум                 да
# 1     215349                 Снизилась     премиум                 да
# 2     215350                 Снизилась    стандарт                нет
# 3     215351                 Снизилась    стандарт                 да
# 4     215352                 Снизилась    стандарт                нет
# ...      ...                       ...         ...                ...
# 1295  216643           Прежний уровень    стандарт                 да
# 1296  216644           Прежний уровень    стандарт                нет
# 1297  216645           Прежний уровень    стандарт                 да
# 1298  216646           Прежний уровень    стандарт                 да
# 1299  216647           Прежний уровень     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 0                    3.4                     5           121
# ...

# %%
data_min = data_merge[data_merge['покупательская_активность'] == 'Снизилась'].copy()

# %%
display(data_min)
# Out:
#          id покупательская_активность тип_сервиса разрешить_сообщать  \
# 1    215349                 Снизилась     премиум                 да
# 2    215350                 Снизилась    стандарт                нет
# 3    215351                 Снизилась    стандарт                 да
# 4    215352                 Снизилась    стандарт                нет
# 5    215353                 Снизилась    стандарт                 да
# ..      ...                       ...         ...                ...
# 589  215937                 Снизилась     премиум                 да
# 590  215938                 Снизилась    стандарт                 да
# 591  215939                 Снизилась    стандарт                 да
# 592  215940                 Снизилась     премиум                 да
# 593  215941                 Снизилась    стандарт                 да
#
#      маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 1                   4.4                     4           819
# ...

# %%
data_min['суммарная_выручка'] = (
    data_min['выручка_предыдущий_месяц'] 
    + data_min['выручка_препредыдущий_месяц'] 
    + data_min['выручка_текущий_месяц']
)

# %%
result = data_min.groupby('популярная_категория')['суммарная_выручка'].sum()

# %%
result = result.sort_values(ascending=False)

# %%
print("\nСуммарная выручка по категориям (ТОП категорий):")
print(result)
# Out:
# Суммарная выручка по категориям (ТОП категорий):
# популярная_категория
# Товары для детей                        2073541.9
# Косметика и аксесуары                   1619472.3
# Домашний текстиль                       1534500.5
# Кухонная посуда                         1039185.7
# Техника для красоты и здоровья           707606.2
# Мелкая бытовая техника и электроника     412785.2
# Name: суммарная_выручка, dtype: float64

# %%
top_3_categories = result.head(3).index

# %%
df_top_3 = data_min[data_min['популярная_категория'].isin(top_3_categories)].copy()

# %%
grouped_top_3 = df_top_3.groupby('популярная_категория').agg({
    'суммарная_выручка': ['count', 'sum', 'mean'],
    'акционные_покупки': ['mean', 'max', 'min']
})

# %%
print("\nДетальная статистика по этим категориям:")
display(grouped_top_3)
# Out:
# Детальная статистика по этим категориям:
#                       суммарная_выручка                           \
#                                   count        sum          mean
# популярная_категория
# Домашний текстиль                   101  1534500.5  15193.074257
# Косметика и аксесуары               105  1619472.3  15423.545714
# Товары для детей                    145  2073541.9  14300.288966
#
#                       акционные_покупки
#                                    mean   max   min
# популярная_категория
# Домашний текстиль              0.419505  0.99  0.11
# Косметика и аксесуары          0.451333  0.99  0.14
# Товары для детей               0.479517  0.99  0.13
